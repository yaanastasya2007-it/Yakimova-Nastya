# %%
import pygame
pygame.init()
font = pygame.font.SysFont(None, 24)

screen = pygame.display.set_mode((960, 768))
pygame.display.set_caption("Пляж")

running = True
while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

    screen.fill((161, 245, 255))
    pygame.draw.circle(screen, (255, 247, 29), (838, 79), 50)
    
    pygame.draw.circle(screen, (255, 255, 255), (110, 100), 20)
    pygame.draw.circle(screen, (0, 0, 0), (110, 100), 20, 1)

    pygame.draw.circle(screen, (255, 255, 255), (138, 79), 20)
    pygame.draw.circle(screen, (0, 0, 0), (138, 79), 20, 1)

    pygame.draw.circle(screen, (255, 255, 255), (172, 76), 20)
    pygame.draw.circle(screen, (0, 0, 0), (172, 76), 20, 1)

    pygame.draw.circle(screen, (255, 255, 255), (137, 101), 20)
    pygame.draw.circle(screen, (0, 0, 0), (137, 101), 20, 1)   
   
    pygame.draw.circle(screen, (255, 255, 255), (170, 101), 20)
    pygame.draw.circle(screen, (0, 0, 0), (170, 101), 20, 1)

    pygame.draw.circle(screen, (255, 255, 255), (195, 93), 20)
    pygame.draw.circle(screen, (0, 0, 0), (195, 93), 20, 1)  

    pygame.draw.polygon(screen, (68, 35, 223), [(-5, 349), (1000, 349), (1000, 762), (-5, 762)])
    pygame.draw.polygon(screen, (238, 246, 12), [(-5, 535), (1000, 535), (1000, 770), (-5, 770)])
    pygame.draw.polygon(screen, (227, 130, 25), [(163, 497), (168, 497), (168, 647), (163, 647)])
    pygame.draw.polygon(screen, (244, 81, 81), [(78, 498), (164, 448), (260, 498)])
    pygame.draw.polygon(screen, (186, 80, 5), [(562, 404), (697, 404), (697, 436), (562, 436)])
    pygame.draw.polygon(screen, (186, 80, 5), [(697, 404), (756, 404), (697, 436)])
    
    pygame.draw.polygon(screen, (0, 0, 0), [(613, 404), (613, 231), (620, 231), (620, 404)])
    pygame.draw.polygon(screen, (222,213, 153), [(620, 231), (713, 306), (660, 306)])
    pygame.draw.line(screen, (133, 128, 92), (660, 306),(713, 306), 3) 
    pygame.draw.polygon(screen, (222,213, 153), [(660, 306),(713, 306), (620,380)])
    pygame.draw.circle(screen, (255, 255, 255), (711, 416), 5)
    pygame.draw.circle(screen, (0, 0, 0), (711, 416), 10, 5)  
    pygame.draw.circle(screen, (186, 80, 5), (562, 404), 32)  
    pygame.draw.line(screen, (157, 70, 59), (562, 404),(562, 436), 1)
    pygame.draw.line(screen, (157, 70, 59), (697, 404), (697, 436), 1)
    pygame.draw.line(screen, (133, 128, 92), (713, 306),(620, 380), 1)
    pygame.draw.line(screen, (133, 128, 92), (713, 306),(618, 231), 1)
    pygame.draw.line(screen, (133, 128, 92),(618, 231),(660, 306), 1)
    pygame.draw.line(screen, (133, 128, 92),(660, 306), (620,380), 1)
    pygame.draw.polygon(screen, (68, 35, 223), [(515, 404), (603, 404), (603, 357), (515, 357)])
    mx, my = pygame.mouse.get_pos()
    text = font.render(f"x: {mx}, y: {my}", True, (0, 0, 0))
    screen.blit(text, (10, 10))
    

    pygame.display.flip()
    

pygame.quit()
